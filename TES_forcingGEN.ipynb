# %%
# data_partition module for batch processing
# based on array_split and function definition

import os,sys 
import netCDF4 as nc
import numpy as np
from time import process_time
from datetime import datetime

# Get current date
current_date = datetime.now()
# Format date to mmddyyyy
formatted_date = current_date.strftime('%m%d%Y')

def forcing_save_1dTES(input_path, file, var_name, period, time, output_path):
    # Open a new NetCDF file to write the data to. For format, you can choose from
    # 'NETCDF3_CLASSIC', 'NETCDF3_64BIT', 'NETCDF4_CLASSIC', and 'NETCDF4'
    source_file = input_path + '/'+ file
    src = nc.Dataset(source_file, 'r', format='NETCDF4')
    
    # Parse the filename into separate substrings
    parts = file.split('.')
    parts.insert(3, '1d')
    # Join the parts back together to form the new filename
    new_filename = '.'.join(parts)
    
    total_rows = src.dimensions['lon'].size
    total_cols = src.dimensions['lat'].size
    total_time = src.dimensions['time'].size

    #print('total timesteps is :' + str(total_timesteps))
    if time == -1:
        time = total_time

    lat= src['lat'][:]
    lon= src['lon'][:]

    lonxy, latxy = np.meshgrid(lon, lat)

    print(lonxy.shape)

    # time in 'days since ' current yyyy-mm-01-01 00:00:00
    data_time = src['time'][0:time] # read (time, y, x) format
    tunit = src.variables['time'].getncattr('units')  # Kao's data is with datetime of leap-year 
    t0=str(tunit.lower()).strip('days since')
    t0=datetime.strptime(t0,'%Y-%m-%d %X')
    iyr = t0.year + np.floor(data_time/365.0)
    data_time0 = datetime.strptime(str(int(iyr[0]))+'-01-01','%Y-%m-%d')
    data_time0 = (data_time0-t0).total_seconds()/86400.0  # days from t0 at the beginning of year
    iday = data_time - data_time0   # now in DOY of leapyear format, will be re-filled below
    imm = np.zeros_like(iday)
    mdoy = [0, 31, 59, 90, 120, 151, 181, 212, 243, 273, 304, 334, 365]
    for m in range(1,12):
        tpts = np.where((iday>mdoy[m-1]) & (iday<=mdoy[m]))
        if (len(tpts[0])>0): 
            imm[tpts] = m             # in MM, may be 1 day off for leap-year
            iday[tpts]= iday[tpts]-mdoy[m-1]     # day of current month 
 
    data_time=iday          # in days of current year-month
    tunit = tunit.replace(str(t0.year).zfill(4)+'-', str(int(iyr[0])).zfill(4)+'-')
    tunit = tunit.replace('-'+str(t0.month).zfill(2)+'-', '-'+str(int(imm[0])).zfill(2)+'-')
    if(tunit.endswith(' 00') and not tunit.endswith(' 00:00:00')):
        tunit=tunit+':00:00'
    
    # Get mask and create gridID, latxy, lonxy first
    
    for name, variable in src.variables.items():
        
        # Check if the last two dimensions are lat and lon
        # Get the mask and create gridIDs, latxy, longxy
        
        if (variable.dimensions[-2:] == ('lat', 'lon')):
            
            data = src[name][0:1, :, :]
            #create a land mask
            mask = data[0]    # data is in (time, Y, X) format
            mask = np.where(~np.isnan(mask), 1, np.nan)

            #create gridIDs
            total_gridcells = total_rows * total_cols
            grid_ids = np.linspace(0, total_gridcells-1, total_gridcells, dtype=int)
            grid_ids = grid_ids.reshape(total_cols,total_rows)

             # create a flattened list of land gridID
            grid_ids = np.multiply(mask,grid_ids)
            grid_ids = grid_ids[~np.isnan(grid_ids)]

            print(lonxy.shape, latxy.shape, mask.shape)
            latxy = np.multiply(mask,latxy)
            latxy1 = latxy[~np.isnan(latxy)]
            lonxy = np.multiply(mask,lonxy)
            lonxy1 = lonxy[~np.isnan(lonxy)]

            # convert local grid_id_lists into an array
            grid_id_arr = np.array(grid_ids)

            lonxy_arr= np.array(lonxy1)
            latxy_arr= np.array(latxy1)
    
    
    dst_name = output_path + '/'+ new_filename

    # Open a new NetCDF file to write the data to. For format, you can choose from
    # 'NETCDF3_CLASSIC', 'NETCDF3_64BIT', 'NETCDF4_CLASSIC', and 'NETCDF4'
    dst = nc.Dataset(dst_name, 'w', format='NETCDF4')
    dst.title = var_name + '('+period+') creted from '+ input_path +' on ' +formatted_date

    # create the gridIDs, lon, and lat variable
    x = dst.createDimension('time', time)
    x = dst.createDimension('ni', grid_id_arr.size)
    x = dst.createDimension('nj', 1)

    w_nc_var = dst.createVariable('gridID', np.int32, ('nj','ni'))
    #  set variable attributes
    w_nc_var.long_name = "gridId in the NA domain" ;
    w_nc_var.decription = "Covers all land and ocean gridcells, with #0 at the upper left corner of the domain" ;
    dst.variables['gridID'][...] = grid_id_arr.reshape(grid_id_arr.size,1)

    # Copy the variables from the source to the target

    
    for name, variable in src.variables.items():
        #if (name == var_name):
        start = process_time()
        print("Working on varibale: "+ name + " dimensions: " + str(variable.dimensions))
        
        # Check if the last two dimensions are lat and lon and save the data 
        
        if (variable.dimensions[-2:] == ('lat', 'lon') ) :
            
            data = src[name][0:time, :, :]
            
            # extract the data over land gridcells
            landcells = len(grid_ids)    
            data = np.multiply(mask, data)
            data = data[~np.isnan(data)]
            data = np.reshape(data,(time,landcells))

            data_arr = np.array(data)
            
            w_nc_var = dst.createVariable(name, np.float32, ('time', 'nj', 'ni'), zlib=True, complevel=5)
            dst.variables[name][:] =data_arr.reshape(time,grid_id_arr.size)
            for attr_name in variable.ncattrs():
                dst[name].setncattr(attr_name, variable.getncattr(attr_name))
        
        if (name == 'time'):
            dvname = 'time'
            w_nc_var = dst.createVariable(dvname, np.float32, ('time'))
            dst.variables[dvname][...] = data_time
            for attr_name in variable.ncattrs():
                if 'units' in attr_name:
                    dst[dvname].units = tunit
                else:
                    dst[dvname].setncattr(attr_name, variable.getncattr(attr_name))

        if (name == 'lat'):
            dvname = 'LATIXY'
            w_nc_var = dst.createVariable(dvname, np.float64, ('nj','ni'))
            dst.variables[dvname][...] = latxy_arr
            for attr_name in variable.ncattrs():
                dst[dvname].setncattr(attr_name, variable.getncattr(attr_name))

        if (name == 'lon'):
            dvname = 'LONGXY'
            w_nc_var = dst.createVariable(dvname, np.float64, ('nj','ni'))
            dst.variables[dvname][...] = lonxy_arr
            for attr_name in variable.ncattrs():
                dst[dvname].setncattr(attr_name, variable.getncattr(attr_name))

    src.close()  # close the source file 
    dst.close()  # close the new file        
    
def get_files(input_path):
    print(input_path)
    files = os.listdir(input_path) 

    files.sort() 

    file_no =0

    files_nc = [f for f in files if (f[-2:] == 'nc')] 
    print("total " + str(len(files_nc)) + " files need to be processed")
    return files_nc


#input_path = "/gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2014/TPHWL3Hrly/"
input_path = "/gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/"
#input_path = "/gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2014/Solar3Hrly/"
output_path = "./temp/"
time = 1
'''
files_nc = get_files(input_path)

for f in files_nc: 
    if (not f.startswith('clmforc')): continue
    parts = f.split('.')
    common_string = parts[0]
    project=parts[1]
    res = parts[2]
    var_name = parts[3]
    period = parts[4]
    print('processing '+ var_name + '(' + period + ') in the file ' + f )
    start = process_time() 
    forcing_save_1dTES(input_path, f, var_name, period, time, output_path)
    end = process_time()
    print("Generating 1D forcing data takes {}".format(end-start))
'''

# Iterate over all subdirectories in the input directory
for root, dirs, files in os.walk(input_path):
    for file in files:
        # Check if the file ends with '.nc'
        if file.endswith('.nc'):
            # Parse the filename into separate substrings
            parts = file.split('.')
            var_name = parts[3]
            period = parts[4]         
            print('processing '+ var_name + '(' + period + ') in the file ' + file )
            # Create the corresponding subfolder in the output directory
            new_dir = os.path.join(output_path, os.path.relpath(root, input_path))
            os.makedirs(new_dir, exist_ok=True)
            start = process_time()
            # Copy the file to the new location
            print(root, new_dir)
            forcing_save_1dTES(root, file, var_name, period, time, new_dir)
            end = process_time()
            print("Generating 1D forcing data takes {}".format(end-start))
# Out:
# processing Prec(2003-01) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.2003-01.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2003/Precip3Hrly ./temp/netcdf/2003/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.0709778270000001
# processing TPQWL(2003-07) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.2003-07.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2003/TPHWL3Hrly ./temp/netcdf/2003/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.43599797099999904
# processing Solr(2003-05) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.2003-05.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2003/Solar3Hrly ./temp/netcdf/2003/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.09995032700000195
# processing Prec(2004-10) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.2004-10.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2004/Precip3Hrly ./temp/netcdf/2004/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.05203847099999592
# processing TPQWL(2004-05) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.2004-05.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2004/TPHWL3Hrly ./temp/netcdf/2004/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.4350720269999968
# processing Solr(2004-12) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.2004-12.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2004/Solar3Hrly ./temp/netcdf/2004/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.0915692820000018
# processing Prec(2005-07) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.2005-07.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2005/Precip3Hrly ./temp/netcdf/2005/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.068845931999995
# processing TPQWL(2005-05) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.2005-05.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2005/TPHWL3Hrly ./temp/netcdf/2005/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.4341252649999987
# processing Solr(2005-01) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.2005-01.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2005/Solar3Hrly ./temp/netcdf/2005/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.09144363100000419
# processing Prec(2006-02) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.2006-02.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2006/Precip3Hrly ./temp/netcdf/2006/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.062159318999995605
# processing TPQWL(2006-08) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.2006-08.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2006/TPHWL3Hrly ./temp/netcdf/2006/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.4342534550000039
# processing Solr(2006-04) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.2006-04.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2006/Solar3Hrly ./temp/netcdf/2006/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.09951699799999858
# processing Prec(2014-10) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.2014-10.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2014/Precip3Hrly ./temp/netcdf/2014/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.06448338199999881
# processing TPQWL(2014-05) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.2014-05.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2014/TPHWL3Hrly ./temp/netcdf/2014/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.4317283319999987
# processing Solr(2014-04) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.2014-04.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2014/Solar3Hrly ./temp/netcdf/2014/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.09994575599999678
# processing Prec(2000-11) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.2000-11.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2000/Precip3Hrly ./temp/netcdf/2000/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.05693079200000284
# processing TPQWL(2000-04) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.2000-04.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2000/TPHWL3Hrly ./temp/netcdf/2000/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.4333422589999998
# processing Solr(2000-07) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.2000-07.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2000/Solar3Hrly ./temp/netcdf/2000/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.100505493
# processing Prec(1987-04) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.1987-04.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1987/Precip3Hrly ./temp/netcdf/1987/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.0644942270000044
# processing TPQWL(1987-09) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.1987-09.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1987/TPHWL3Hrly ./temp/netcdf/1987/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.4325858969999956
# processing Solr(1987-02) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.1987-02.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1987/Solar3Hrly ./temp/netcdf/1987/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.09759100200000148
# processing Prec(2001-09) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.2001-09.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2001/Precip3Hrly ./temp/netcdf/2001/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.0705094600000038
# processing TPQWL(2001-06) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.2001-06.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2001/TPHWL3Hrly ./temp/netcdf/2001/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.4357330939999997
# processing Solr(2001-08) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.2001-08.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2001/Solar3Hrly ./temp/netcdf/2001/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.10076240600000119
# processing Prec(1988-08) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.1988-08.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1988/Precip3Hrly ./temp/netcdf/1988/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.0668473620000043
# processing TPQWL(1988-08) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.1988-08.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1988/TPHWL3Hrly ./temp/netcdf/1988/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.43486079499999875
# processing Solr(1988-05) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.1988-05.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1988/Solar3Hrly ./temp/netcdf/1988/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.09879195899999615
# processing Prec(2002-02) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.2002-02.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2002/Precip3Hrly ./temp/netcdf/2002/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.06598820399999994
# processing TPQWL(2002-08) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.2002-08.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2002/TPHWL3Hrly ./temp/netcdf/2002/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.4323817699999992
# processing Solr(2002-02) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.2002-02.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2002/Solar3Hrly ./temp/netcdf/2002/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.09740335099999697
# processing Prec(1989-04) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.1989-04.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1989/Precip3Hrly ./temp/netcdf/1989/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.05766313499999853
# processing TPQWL(1989-02) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.1989-02.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1989/TPHWL3Hrly ./temp/netcdf/1989/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.431379610999997
# processing Solr(1989-09) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.1989-09.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1989/Solar3Hrly ./temp/netcdf/1989/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.09979558599999905
# processing Prec(2010-07) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.2010-07.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2010/Precip3Hrly ./temp/netcdf/2010/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.06998866400000026
# processing TPQWL(2010-11) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.2010-11.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2010/TPHWL3Hrly ./temp/netcdf/2010/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.432292326999999
# processing Solr(2010-11) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.2010-11.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2010/Solar3Hrly ./temp/netcdf/2010/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.09711610099999746
# processing Prec(1997-11) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.1997-11.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1997/Precip3Hrly ./temp/netcdf/1997/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.07290161000000239
# processing TPQWL(1997-10) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.1997-10.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1997/TPHWL3Hrly ./temp/netcdf/1997/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.4319566770000023
# processing Solr(1997-02) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.1997-02.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1997/Solar3Hrly ./temp/netcdf/1997/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.09826794800000016
# processing Prec(1983-09) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.1983-09.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1983/Precip3Hrly ./temp/netcdf/1983/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.05774433499999532
# processing TPQWL(1983-08) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.1983-08.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1983/TPHWL3Hrly ./temp/netcdf/1983/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.43466052699999835
# processing Solr(1983-10) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.1983-10.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1983/Solar3Hrly ./temp/netcdf/1983/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.09897280899999572
# processing Prec(2011-05) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.2011-05.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2011/Precip3Hrly ./temp/netcdf/2011/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.061328143999993756
# processing TPQWL(2011-08) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.2011-08.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2011/TPHWL3Hrly ./temp/netcdf/2011/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.4350058329999982
# processing Solr(2011-12) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.2011-12.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2011/Solar3Hrly ./temp/netcdf/2011/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.09468083499999835
# processing Prec(1998-03) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.1998-03.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1998/Precip3Hrly ./temp/netcdf/1998/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.06753139300000299
# processing TPQWL(1998-06) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.1998-06.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1998/TPHWL3Hrly ./temp/netcdf/1998/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.4366051069999983
# processing Solr(1998-09) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.1998-09.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1998/Solar3Hrly ./temp/netcdf/1998/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.09945399400000099
# processing Prec(1984-02) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.1984-02.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1984/Precip3Hrly ./temp/netcdf/1984/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.055808386999999016
# processing TPQWL(1984-05) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.1984-05.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1984/TPHWL3Hrly ./temp/netcdf/1984/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.4340652679999977
# processing Solr(1984-04) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.1984-04.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1984/Solar3Hrly ./temp/netcdf/1984/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.09971461599999998
# processing Prec(2012-09) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.2012-09.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2012/Precip3Hrly ./temp/netcdf/2012/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.06186183300000181
# processing TPQWL(2012-11) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.2012-11.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2012/TPHWL3Hrly ./temp/netcdf/2012/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.4328857630000016
# processing Solr(2012-03) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.2012-03.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2012/Solar3Hrly ./temp/netcdf/2012/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.09933418399999994
# processing Prec(1999-05) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.1999-05.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1999/Precip3Hrly ./temp/netcdf/1999/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.051517567999994185
# processing TPQWL(1999-06) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.1999-06.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1999/TPHWL3Hrly ./temp/netcdf/1999/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.4367742880000023
# processing Solr(1999-01) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.1999-01.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1999/Solar3Hrly ./temp/netcdf/1999/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.09292537800000389
# processing Prec(1985-01) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.1985-01.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1985/Precip3Hrly ./temp/netcdf/1985/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.05711384099999606
# processing TPQWL(1985-07) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.1985-07.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1985/TPHWL3Hrly ./temp/netcdf/1985/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.43620804700000093
# processing Solr(1985-09) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.1985-09.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1985/Solar3Hrly ./temp/netcdf/1985/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.09927129400000467
# processing Prec(2013-06) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.2013-06.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2013/Precip3Hrly ./temp/netcdf/2013/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.07227853999999923
# processing TPQWL(2013-03) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.2013-03.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2013/TPHWL3Hrly ./temp/netcdf/2013/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.4317758699999956
# processing Solr(2013-10) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.2013-10.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2013/Solar3Hrly ./temp/netcdf/2013/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.10001692099999815
# processing Prec(1986-06) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.1986-06.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1986/Precip3Hrly ./temp/netcdf/1986/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.057490812999994034
# processing TPQWL(1986-12) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.1986-12.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1986/TPHWL3Hrly ./temp/netcdf/1986/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.4312501259999948
# processing Solr(1986-01) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.1986-01.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1986/Solar3Hrly ./temp/netcdf/1986/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.09320762099999769
# processing Prec(1993-09) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.1993-09.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1993/Precip3Hrly ./temp/netcdf/1993/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.07011024500000218
# processing TPQWL(1993-04) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.1993-04.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1993/TPHWL3Hrly ./temp/netcdf/1993/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.4330483940000036
# processing Solr(1993-12) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.1993-12.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1993/Solar3Hrly ./temp/netcdf/1993/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.09134445100000477
# processing Prec(1994-10) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.1994-10.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1994/Precip3Hrly ./temp/netcdf/1994/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.06259136300000279
# processing TPQWL(1994-12) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.1994-12.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1994/TPHWL3Hrly ./temp/netcdf/1994/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.4331111309999969
# processing Solr(1994-03) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.1994-03.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1994/Solar3Hrly ./temp/netcdf/1994/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.1006725300000042
# processing Prec(1980-09) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.1980-09.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1980/Precip3Hrly ./temp/netcdf/1980/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.06918704199999581
# processing TPQWL(1980-03) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.1980-03.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1980/TPHWL3Hrly ./temp/netcdf/1980/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.43256517999999744
# processing Solr(1980-05) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.1980-05.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1980/Solar3Hrly ./temp/netcdf/1980/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.09843997099999768
# processing Prec(1995-02) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.1995-02.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1995/Precip3Hrly ./temp/netcdf/1995/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.061055020000004845
# ...
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.4349063209999997
# processing Solr(1981-07) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.1981-07.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1981/Solar3Hrly ./temp/netcdf/1981/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.09948789499999577
# processing Prec(1996-09) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.1996-09.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1996/Precip3Hrly ./temp/netcdf/1996/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.05975354000000266
# processing TPQWL(1996-07) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.1996-07.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1996/TPHWL3Hrly ./temp/netcdf/1996/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.4332933350000019
# processing Solr(1996-09) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.1996-09.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1996/Solar3Hrly ./temp/netcdf/1996/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.09859492199999664
# processing Prec(1982-03) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.1982-03.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1982/Precip3Hrly ./temp/netcdf/1982/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.061442356000000586
# processing TPQWL(1982-02) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.1982-02.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1982/TPHWL3Hrly ./temp/netcdf/1982/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.4335099450000044
# processing Solr(1982-08) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.1982-08.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1982/Solar3Hrly ./temp/netcdf/1982/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.09986518499999875
# processing Prec(2007-12) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.2007-12.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2007/Precip3Hrly ./temp/netcdf/2007/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.06264124999999865
# processing TPQWL(2007-02) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.2007-02.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2007/TPHWL3Hrly ./temp/netcdf/2007/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.434607714000002
# processing Solr(2007-01) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.2007-01.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2007/Solar3Hrly ./temp/netcdf/2007/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.09251571600000119
# processing Prec(1990-11) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.1990-11.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1990/Precip3Hrly ./temp/netcdf/1990/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.06082305400000365
# processing TPQWL(1990-06) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.1990-06.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1990/TPHWL3Hrly ./temp/netcdf/1990/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.4350615480000002
# processing Solr(1990-01) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.1990-01.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1990/Solar3Hrly ./temp/netcdf/1990/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.0920234979999961
# processing Prec(2008-11) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.2008-11.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2008/Precip3Hrly ./temp/netcdf/2008/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.05412608900000038
# processing TPQWL(2008-08) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.2008-08.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2008/TPHWL3Hrly ./temp/netcdf/2008/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.4336911790000002
# processing Solr(2008-04) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.2008-04.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2008/Solar3Hrly ./temp/netcdf/2008/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.0992369009999976
# processing Prec(1991-10) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.1991-10.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1991/Precip3Hrly ./temp/netcdf/1991/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.062317600000000084
# processing TPQWL(1991-12) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.1991-12.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1991/TPHWL3Hrly ./temp/netcdf/1991/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.43369116799999574
# processing Solr(1991-02) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.1991-02.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1991/Solar3Hrly ./temp/netcdf/1991/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.10051115899999985
# processing Prec(2009-09) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.2009-09.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2009/Precip3Hrly ./temp/netcdf/2009/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.052753729999999166
# processing TPQWL(2009-09) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.2009-09.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2009/TPHWL3Hrly ./temp/netcdf/2009/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.43524780599999957
# processing Solr(2009-06) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.2009-06.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/2009/Solar3Hrly ./temp/netcdf/2009/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.09987455499999953
# processing Prec(1992-05) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Prec.1992-05.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1992/Precip3Hrly ./temp/netcdf/1992/Precip3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: PRECTmms dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.06549190599999832
# processing TPQWL(1992-09) in the file clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.1992-09.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1992/TPHWL3Hrly ./temp/netcdf/1992/TPHWL3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: TBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: QBOT dimensions: ('time', 'lat', 'lon')
# Working on varibale: PSRF dimensions: ('time', 'lat', 'lon')
# Working on varibale: FLDS dimensions: ('time', 'lat', 'lon')
# Working on varibale: WIND dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.43456769100000514
# processing Solr(1992-10) in the file clmforc.Daymet_GSWP3_TESSFA.4km.Solr.1992-10.nc
# /gpfs/wolf2/cades/cli185/proj-shared/Daymet_GSWP3_4KM_TESSFA/netcdf/1992/Solar3Hrly ./temp/netcdf/1992/Solar3Hrly
# (769, 1705)
# (769, 1705) (769, 1705) (769, 1705)
# Working on varibale: lon dimensions: ('lon',)
# Working on varibale: lat dimensions: ('lat',)
# Working on varibale: time dimensions: ('time',)
# Working on varibale: FSDS dimensions: ('time', 'lat', 'lon')
# Generating 1D forcing data takes 0.09781433199999867

# %%
# Given string
s = "clmforc.Daymet_GSWP3_TESSFA.4km.TPQWL.2014-12.nc"

# Split the string into substrings
parts = s.split('.')

# Print the substrings
for i, part in enumerate(parts):
    print(f"Part {i+1}: {part}")
# Out:
# Part 1: clmforc
# Part 2: Daymet_GSWP3_TESSFA
# Part 3: 4km
# Part 4: TPQWL
# Part 5: 2014-12
# Part 6: nc

# %%
new_dir
# Out:
# './temp/netcdf/netcdf/2003/Precip3Hrly'

# %%
parts[-2]
# Out:
# '2014-12'
